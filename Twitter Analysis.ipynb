# %% [markdown]
# Descriptive statistics about job id 1160 (tornado).

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import MySQLdb as mdb
import sys
import pandas as pd
import numpy as np
from collections import Counter
from collections import OrderedDict
import matplotlib.pyplot as plt

con = mdb.connect('opendata.missouri.edu', 'datascience', 'datascience', 'datascience');
csv = 'Data/1160_data.csv'

# %%
sql = "SELECT * FROM tweet WHERE job_id = 1160"
tweets = pd.read_sql_query(sql, con, parse_dates=['created_at'])

# %%
tweets.to_csv(csv, index=False)

# %%
types = {
    'tweet_id_str': 'object',
    'job_id': 'int64',
    'text': 'object',
    'from_user': 'object',
    'from_user_id_str': 'object',
    'from_user_name': 'object',
    'from_user_fullname': 'object',
    'from_user_followers': 'int64',
    'from_user_following': 'int64',
    'from_user_favorites': 'int64',
    'from_user_tweets': 'int64',
    'from_user_timezone': 'object',
    'to_user': 'object',
    'to_user_id_str': 'object',
    'to_user_name': 'object',
    'source': 'object',
    'location_geo': 'object',
    'location_geo_0': 'float64',
    'location_geo_1': 'float64',
    'iso_language': 'object',
    'analysis_state': 'int64',
}
#tweets = pd.read_csv(csv, dtype=types, parse_dates='created_at')

# %% [markdown]
# Q1. How many tweets in the collection?

# %%
print("Total number of tweets in job id 1160: " + str(len(tweets.index)))
# Out:
# Total number of tweets in job id 1160: 168882

# %% [markdown]
# Q2. When did the tweets start?

# %%
print("The first tweet was at "+ format(tweets['created_at'].min()))
# Out:
# The first tweet was at 2015-11-22 18:09:56

# %% [markdown]
# Q3. When did the tweets end?

# %%
print("The last tweet was at "+ format(tweets['created_at'].max()))
# Out:
# The last tweet was at 2016-05-05 08:39:57

# %% [markdown]
# Q4. What is the trend for tweet volume?

# %%
allTweets = {}
tweetVolume = {}
groupByMonth = {}

for index, tweet in tweets.iterrows():
    timeOfTweet = pd.Timestamp(tweet.created_at)
    year = timeOfTweet.year
    month = timeOfTweet.month
    week = timeOfTweet.week
    
    try:
        allTweets[str(year) + '-' + str(month) + ' week: ' + str(week)].append(tweet)
    except KeyError:
        allTweets[str(year) + '-' + str(month) + ' week: ' + str(week)] = []
        allTweets[str(year) + '-' + str(month) + ' week: ' + str(week)].append(tweet)

for k, t in allTweets.items():
    tweetVolume[k] = len(t)
tweetVolume
# Out:
# {'2015-11 week: 47': 55,
#  '2015-11 week: 48': 1751,
#  '2015-11 week: 49': 252,
#  '2015-12 week: 49': 1922,
#  '2015-12 week: 50': 3142,
#  '2015-12 week: 51': 3880,
#  '2015-12 week: 52': 36009,
#  '2015-12 week: 53': 7232,
#  '2016-1 week: 1': 3875,
#  '2016-1 week: 2': 5074,
#  '2016-1 week: 3': 3102,
#  '2016-1 week: 4': 5943,
#  '2016-1 week: 53': 891,
#  '2016-2 week: 5': 11849,
#  '2016-2 week: 6': 1145,
#  '2016-2 week: 7': 4971,
#  '2016-2 week: 8': 18854,
#  '2016-2 week: 9': 368,
#  '2016-3 week: 10': 5176,
#  '2016-3 week: 11': 6259,
#  '2016-3 week: 12': 886,
#  '2016-3 week: 13': 6284,
#  '2016-3 week: 9': 2306,
#  '2016-4 week: 13': 4033,
#  '2016-4 week: 14': 3634,
#  '2016-4 week: 15': 9905,
#  '2016-4 week: 16': 4376,
#  '2016-4 week: 17': 12841,
#  '2016-5 week: 17': 442,
#  '2016-5 week: 18': 2425}

# %% [markdown]
# Q5. If you look at the most common words over the lifetime of the search, do you notice any particular trends associated with those words?

# %%
tweets['text'] = tweets['text'].astype(str).str.lower()
Counter(" ".join(tweets["text"]).split()).most_common(50)
# Out:
# [('#tornado', 149973),
#  ('rt', 112068),
#  ('in', 52640),
#  ('the', 46912),
#  ('of', 40570),
#  ('a', 33240),
#  ('for', 24636),
#  ('to', 20605),
#  ('and', 18168),
#  ('on', 16729),
#  ('from', 15466),
#  ('this', 15325),
#  ('tornado', 14989),
#  ('near', 14652),
#  ('@weatherchannel:', 12899),
#  ('is', 12687),
#  ('warning', 11689),
#  ('watch', 11430),
#  ('at', 10981),
#  ('&amp;', 10906),
#  ('until', 10576),
#  ('de', 10248),
#  ('damage', 10183),
#  ('#txwx', 10102),
#  ('en', 8640),
#  ('pm', 7707),
#  ('you', 7529),
#  ('storm', 7161),
#  ('#weather', 6838),
#  ('by', 6680),
#  ('-', 6544),
#  ('via', 6362),
#  ('with', 6361),
#  ('take', 6194),
#  ('as', 5757),
#  ('#mswx', 5752),
#  ('@stormchaser4850:', 5490),
#  ('#dfwwx', 5463),
#  ('just', 5406),
#  ('video', 5264),
#  ('moving', 5230),
#  ('new', 5187),
#  ('possible', 5180),
#  ('#alwx', 5106),
#  ('now', 4971),
#  ('confirmed', 4758),
#  ('el', 4703),
#  ('was', 4691),
#  ('large', 4687),
#  ('la', 4592)]

# %% [markdown]
# Ignoring all of the small filler words(in, the, of, etc.), the most common words are associated with sending alerts(warning. watch, @weatherchannel) and advising people to take the proper precautionary action(take,damage,possible).

# %% [markdown]
# Q6. What external events might correspond with the differences in the trends of most common words?

# %% [markdown]
# The location of the tornado could be a factor in the number of tweets. For instance, a tornado near a large city would generate more tweets than a tornado in a remote location. Also the severity of the storm could be a reason why some words are used more frequently. Tornadoes that cause a lot of damage would definetly be more newsworthy than a funnel cloud that does not even touch down, even though there may still be a tornado watch.

# %% [markdown]
# Q7. What hashtags show up as most prominent in each month of the lifecycle?

# %%
popHashtags = {}
for k, t in allTweets.items():
    popHashtags[k] = []
    for tweet in t:
        text = str(tweet['text']).lower()
        if len(text) > 0 and text != 'nan':
            for word in text.split():
                if word[0] == "#":
                    popHashtags[k].append(word)
    popHashtags[k] = Counter(popHashtags[k]).most_common()[:20]
popHashtags
# Out:
# {'2015-11 week: 47': [('#tornado', 54),
#   ('#climate', 15),
#   ('#nevada', 5),
#   ('#brasil', 5),
#   ('#chicago', 4),
#   ('#broward', 3),
#   ('#paraná,', 3),
#   ('#tooth', 3),
#   ('#yellow', 3),
#   ('#grimstad', 3),
#   ('#try', 3),
#   ('#me', 2),
#   ('#california', 2),
#   ('#dusk', 2),
#   ('#photos', 2),
#   ('#hawk', 2),
#   ('#honda', 2),
#   ('#wx', 2),
#   ('#christmasgifts', 2),
#   ('#okwx.', 2)],
#  '2015-11 week: 48': [('#tornado', 1458),
#   ('#excited', 126),
#   ('#trailerpark', 126),
#   ('#superman', 101),
#   ('#acoustic', 98),
#   ('#tooth', 82),
#   ('#grimstad', 82),
#   ('#try', 82),
#   ('#syrien', 82),
#   ('#yellow', 82),
#   ('#music', 74),
#   ('#lightning', 71),
#   ('#october21', 68),
#   ('#destrozos', 67),
#   ('#weather', 67),
#   ('#chaco:', 66),
#   ('#christmasgifts', 62),
#   ('#stormhour', 52),
#   ('#fire', 49),
#   ('#bundeswehr', 48)],
#  '2015-11 week: 49': [('#tornado', 195),
#   ('#britishredcross', 56),
#   ('#8f', 56),
#   ('#giveblood', 56),
#   ('#svr', 56),
#   ('#tornado-einsatz', 33),
#   ('#tooth', 17),
#   ('#yellow', 17),
#   ('#try', 17),
#   ('#grimstad', 17),
#   ('#christmasgifts', 13),
#   ('#txwx', 11),
#   ('#severe', 10),
#   ('#okwx', 10),
#   ('#kswx', 10),
#   ('#cowx', 10),
#   ('#california', 9),
#   ('#video', 8),
#   ('#storms', 8),
#   ('#australia', 7)],
#  '2015-12 week: 49': [('#tornado', 1504),
#   ('#thewizlive', 423),
#   ('#peterpanlive', 205),
#   ('#syrien', 194),
#   ('#raf', 158),
#   ('#syrieneinsatz', 143),
#   ('#syria', 118),
#   ('#syrien:', 93),
#   ('#tooth', 91),
#   ('#grimstad', 91),
#   ('#try', 91),
#   ('#yellow', 91),
#   ('#bundeswehr', 90),
#   ('#tornado-einsatz.', 90),
#   ('#christmasgifts', 69),
#   ('#jets', 53),
#   ('#weather', 52),
#   ('#daesh', 49),
#   ('#isis', 47),
#   ('#california', 46)],
#  '2015-12 week: 50': [('#tornado', 2873),
#   ('#txwx', 288),
#   ('#wawx', 181),
#   ('#weather', 151),
#   ('#lindale', 150),
#   ('#khou11', 144),
#   ('#flood', 137),
#   ('#tx', 122),
#   ('#battleground', 116),
#   ('#tooth', 115),
#   ('#grimstad', 115),
#   ('#try', 115),
#   ('#yellow', 115),
#   ('#video:', 96),
#   ('#texas', 89),
#   ('#abc13', 88),
#   ('#hounews', 85),
#   ('#abc13eyewitness', 85),
#   ('#funnelcloud', 85),
#   ('#christmasgifts', 85)],
#  '2015-12 week: 51': [('#tornado', 3455),
#   ('#sydneystorm', 574),
#   ('#acuña', 469),
#   ('#sydney', 435),
#   ('#coahuila', 236),
#   ('#ciudadacuña,', 196),
#   ('#coahuila,', 176),
#   ('#kurnell', 144),
#   ('#tornado,but', 139),
#   ('#huntershill.', 135),
#   ('#weather', 126),
#   ('#tooth', 117),
#   ('#grimstad', 117),
#   ('#try', 117),
#   ('#yellow', 117),
#   ('#australia', 93),
#   ('#méxico,', 89),
#   ('#storm', 86),
#   ('#christmasgifts', 86),
#   ('#hail', 85)],
#  '2015-12 week: 52': [('#tornado', 33961),
#   ('#txwx', 5857),
#   ('#dfwwx', 3823),
#   ('#mswx', 2957),
#   ('#dallas', 2256),
#   ('#rowlett', 2224),
#   ('#texas', 1991),
#   ('#garland', 1174),
#   ('#alwx', 1090),
#   ('#wfaaweather', 921),
#   ('#texasweather', 895),
#   ('#mississippi', 841),
#   ('#tornadodamage', 763),
#   ('#arwx', 707),
#   ('#tnwx', 705),
#   ('#garland.', 640),
#   ('#tornado.', 635),
#   ('#dallastornado', 480),
#   ('#warning', 468),
#   ('#weather', 462)],
#  '2015-12 week: 53': [('#tornado', 6415),
#   ('#dfwwx', 1011),
#   ('#txwx', 997),
#   ('#texas', 534),
#   ('#garland', 450),
#   ('#rowlett', 418),
#   ('#flwx', 339),
#   ('#alwx', 337),
#   ('#arwx', 298),
#   ('#tornado:', 285),
#   ('#weather', 267),
#   ('#garland.', 262),
#   ('#dallas...', 243),
#   ('#dallas', 240),
#   ('#tornadodamage', 210),
#   ('#mswx', 186),
#   ('#ncwx', 176),
#   ('#alabama', 165),
#   ('#tornado.', 165),
#   ('#holidaystorm', 138)],
#  '2016-1 week: 1': [('#tornado', 3421),
#   ('#capecoral', 293),
#   ('#weather', 250),
#   ('#bic', 249),
#   ('#?gong', 249),
#   ('#backbone', 215),
#   ('#ncas', 196),
#   ('#team2mvch', 193),
#   ('#flwx', 189),
#   ('#flood', 182),
#   ('#garland', 161),
#   ('#????', 146),
#   ('#???', 141),
#   ('#texas', 125),
#   ('#fl', 121),
#   ('#sandiego', 104),
#   ('#cawx', 102),
#   ('#tornado.', 94),
#   ('#elnino', 79),
#   ('#txwx', 76)],
#  '2016-1 week: 2': [('#tornado', 4652),
#   ('#flwx', 751),
#   ('#weather', 636),
#   ('#sarasota', 413),
#   ('#florida', 355),
#   ('#wtsp', 190),
#   ('#siestakey', 134),
#   ('#cyclone', 125),
#   ('#kitten', 124),
#   ('#inspirational', 124),
#   ('#tornado.', 122),
#   ('#elnino', 91),
#   ('#capecoral', 88),
#   ('#duette', 88),
#   ('#blogpost', 82),
#   ('#miracle', 79),
#   ('#prayingforeveryone', 77),
#   ('#manatee', 74),
#   ('#weatherchannel', 72),
#   ('#fl', 65)],
#  '2016-1 week: 3': [('#tornado', 2792),
#   ('#weather', 406),
#   ('#bundeswehr', 128),
#   ('#lawx', 106),
#   ('#mswx', 102),
#   ('#sarasota', 97),
#   ('#nola', 94),
#   ('#florida', 84),
#   ('#syria', 79),
#   ('#wtsp', 73),
#   ('#cyclone', 72),
#   ('#kitten', 67),
#   ('#inspirational', 67),
#   ('#flwx', 64),
#   ('#wx', 63),
#   ('#news', 57),
#   ('#tornadowarning', 57),
#   ('#tornado-pilot', 53),
#   ('#blogpost', 50),
#   ('#miracle', 47)],
#  '2016-1 week: 4': [('#tornado', 3391),
#   ('#weather', 455),
#   ('#flwx', 430),
#   ('#broward', 156),
#   ('#coconutcreek', 155),
#   ('#severe', 137),
#   ('#florida', 117),
#   ('#florida,', 115),
#   ('#inspirational', 91),
#   ('#cyclone', 91),
#   ('#kitten', 91),
#   ('#????????', 80),
#   ('#breaking', 75),
#   ('#tornado:', 72),
#   ('#wx', 66),
#   ('#tornado,', 64),
#   ('#warning', 59),
#   ('#saudi', 58),
#   ('#storm', 57),
#   ('#tornado.', 56)],
#  '2016-1 week: 53': [('#tornado', 829),
#   ('#weather', 116),
#   ('#garland', 59),
#   ('#try', 49),
#   ('#yellow', 49),
#   ('#tooth', 49),
#   ('#grimstad', 49),
#   ('#txwx', 37),
#   ('#christmasgifts', 35),
#   ('#324eltemps', 30),
#   ('#nationalgeographic', 30),
#   ('#cyclone', 27),
#   ('#inspirational', 27),
#   ('#kitten', 27),
#   ('#california', 26),
#   ('#usa', 26),
#   ('#mswx', 25),
#   ('#texas', 25),
#   ('#humanityfirst', 18),
#   ('#rowlett', 17)],
#  '2016-2 week: 5': [('#tornado', 7834),
#   ('#alwx', 1319),
#   ('#mswx', 896),
#   ('#weather', 431),
#   ('#alabama', 285),
#   ('#tnwx', 251),
#   ('#gawx', 237),
#   ('#severe', 223),
#   ('#mississippi', 200),
#   ('#scwx', 173),
#   ('#nashville', 170),
#   ('#birmingham.', 156),
#   ('#wind', 135),
#   ('#ga', 133),
#   ('#wx', 133),
#   ('#news', 127),
#   ('#storm', 112),
#   ('#mufa', 110),
#   ('#creeroreventar', 108),
#   ('#damage', 100)],
#  '2016-2 week: 6': [('#tornado', 1078),
#   ('#rufino', 150),
#   ('#temporal', 148),
#   ('#weather', 107),
#   ('#storms', 97),
#   ('#croatia', 56),
#   ('#cyclone', 39),
#   ('#kitten', 39),
#   ('#inspirational', 39),
#   ('#raf', 35),
#   ('#destrozos', 34),
#   ('#blogpost', 24),
#   ('#miracle', 23),
#   ('#texas', 21),
#   ('#twitter', 19),
#   ('#storm', 19),
#   ('#txwx', 17),
#   ('#earthquake', 15),
#   ('#hackleburg', 15),
#   ('#flickr', 15)],
#  '2016-2 week: 7': [('#tornado', 4426),
#   ('#flwx', 563),
#   ('#weather', 514),
#   ('#alwx', 513),
#   ('#mswx', 465),
#   ('#tornado,', 270),
#   ('#news', 260),
#   ('#nywx', 221),
#   ('#florida', 193),
#   ('#miami', 191),
#   ('#breaking', 146),
#   ('#wx', 142),
#   ('#lawx', 133),
#   ('#storm', 103),
#   ('#mississippi', 93),
#   ('#alabama', 79),
#   ('#tornadowarning', 66),
#   ('#miss.', 63),
#   ('#tornado.', 60),
#   ('#severe', 52)],
#  '2016-2 week: 8': [('#tornado', 17483),
#   ('#lawx', 2704),
#   ('#flwx', 1337),
#   ('#vawx', 1170),
#   ('#pensacola', 939),
#   ('#alwx', 670),
#   ('#ncwx', 498),
#   ('#mswx', 473),
#   ('#storm', 422),
#   ('#weather', 398),
#   ('#virginia', 359),
#   ('#tornado.', 343),
#   ('#southcarolina', 309),
#   ('#tornadowarning', 293),
#   ('#severe', 266),
#   ('#coahuila', 212),
#   ('#va', 203),
#   ('#gawx', 191),
#   ('#la', 191),
#   ('#waverly', 175)],
#  '2016-2 week: 9': [('#tornado', 339),
#   ('#lawx', 97),
#   ('#weather', 34),
#   ('#storm', 17),
#   ('#wrn', 15),
#   ('#tornadosafety', 13),
#   ('#leapday', 12),
#   ('#lightning', 11),
#   ('#nature', 10),
#   ('#meteorologist', 10),
#   ('#photography', 10),
#   ('#clouds,', 10),
#   ('#stormchasers', 10),
#   ('#science', 10),
#   ('#vortexse', 9),
#   ('#tornado?', 9),
#   ('#tornado,', 7),
#   ('#southcarolina', 6),
#   ('#wx', 5),
#   ('#leapyear', 4)],
#  '2016-3 week: 10': [('#tornado', 4981),
#   ('#txwx', 994),
#   ('#arwx', 429),
#   ('#dfwwx', 362),
#   ('#weather', 250),
#   ('#texas', 213),
#   ('#preveniresvivir', 180),
#   ('#okwx', 160),
#   ('#storm', 128),
#   ('#hail', 127),
#   ('#atxwx', 119),
#   ('#oklahoma', 86),
#   ('#rain,', 79),
#   ('#wx', 76),
#   ('#tornadowarning', 71),
#   ('#houston,', 70),
#   ('#storms', 68),
#   ('#flooding', 67),
#   ('#txwx.', 66),
#   ('#arkansas', 66)],
#  '2016-3 week: 11': [('#tornado', 5935),
#   ('#ilwx', 1589),
#   ('#arwx', 560),
#   ('#ohwx', 332),
#   ('#weather', 287),
#   ('#iawx', 262),
#   ('#mowx', 197),
#   ('#tornado.', 168),
#   ('#illinois', 148),
#   ('#arkansas', 136),
#   ('#il', 127),
#   ('#stormhour', 126),
#   ('#news', 104),
#   ('#wx', 100),
#   ('#mswx', 89),
#   ('#onstorm', 88),
#   ('#hail', 82),
#   ('#lsmwx', 78),
#   ('#missouri', 73),
#   ('#tornadowarning', 72)],
#  '2016-3 week: 12': [('#tornado', 835),
#   ('#severe', 69),
#   ('#weather', 68),
#   ('#syrien', 50),
#   ('#arwx', 49),
#   ('#hail', 42),
#   ('#wx', 42),
#   ('#ohiovalley,', 41),
#   ('#south', 41),
#   ('#okwx', 35),
#   ('#inwx', 26),
#   ('#inwxready', 25),
#   ('#storms', 24),
#   ('#news', 23),
#   ('#kswx', 21),
#   ('#storm', 19),
#   ('#arkansas', 19),
#   ('#dfwwx', 16),
#   ('#iawx', 14),
#   ('#evansville', 13)],
#  '2016-3 week: 13': [('#tornado', 6014),
#   ('#okwx', 1760),
#   ('#tulsa', 572),
#   ('#storm', 465),
#   ('#oklahoma', 429),
#   ('#weather', 243),
#   ('#severe', 214),
#   ('#owasso', 178),
#   ('#storms', 168),
#   ('#tulsa,', 132),
#   ('#wtsp', 132),
#   ('#txwx', 123),
#   ('#mswx', 117),
#   ('#hail', 115),
#   ('#tornadowarning', 115),
#   ('#wx', 112),
#   ('#alwx', 108),
#   ('#plains;', 105),
#   ('#torcon', 105),
#   ('#breaking', 99)],
#  '2016-3 week: 9': [('#tornado', 2146),
#   ('#alwx', 390),
#   ('#weather', 138),
#   ('#gifparty', 122),
#   ('#bessemer', 103),
#   ('#lawx', 66),
#   ('#science', 63),
#   ('#alabama', 60),
#   ('#wx', 52),
#   ('#storms', 50),
#   ('#tornado.', 47),
#   ('#news', 46),
#   ('#inwx', 45),
#   ('#al', 40),
#   ('#earth', 37),
#   ('#kywx', 37),
#   ('#flooding', 36),
#   ('#foxnewsus', 35),
#   ('#tornadoes', 28),
#   ('#mswx', 27)],
#  '2016-4 week: 13': [('#tornado', 3846),
#   ('#alwx', 486),
#   ('#gawx', 330),
#   ('#mswx', 296),
#   ('#okwx', 278),
#   ('#winds', 145),
#   ('#weather', 135),
#   ('#tulsa', 108),
#   ('#warning', 100),
#   ('#mississippi', 87),
#   ('#storm', 87),
#   ('#alabama', 81),
#   ('#inwx', 58),
#   ('#eeuu', 50),
#   ('#tornadowarning', 49),
#   ('#tornado.', 49),
#   ('#newhope', 48),
#   ('#southwest', 46),
#   ('#dmv', 46),
#   ('#texas', 43)],
#  '2016-4 week: 14': [('#tornado', 2812),
#   ('#tornado"', 548),
#   ('#nmwx', 544),
#   ('#weather', 184),
#   ('#gtaonline', 162),
#   ('#stormhour', 116),
#   ('#rockstargames', 105),
#   ('#gtav', 102),
#   ('#fairdale', 101),
#   ('#flwx', 100),
#   ('#ilwx', 84),
#   ('#alwx', 71),
#   ('#gta5', 64),
#   ('#storm', 55),
#   ('#declasse', 55),
#   ('#lowrider', 53),
#   ('#tornado.', 53),
#   ('#okwx', 51),
#   ('#pussiriot', 49),
#   ('#wx', 48)],
#  '2016-4 week: 15': [('#tornado', 8892),
#   ('#uruguay', 1250),
#   ('#dolores', 1107),
#   ('#cowx', 533),
#   ('#txwx', 446),
#   ('#okwx', 414),
#   ('#tornado.', 322),
#   ('#uruguay,', 271),
#   ('#weather', 219),
#   ('#hail', 191),
#   ('#tornado"?', 186),
#   ('#wx', 165),
#   ('#calgary', 156),
#   ('#news', 144),
#   ('#tornado,', 144),
#   ('#?????', 143),
#   ('#rt', 121),
#   ('#iraq', 114),
#   ('#sky', 114),
#   ('#wildfire.', 111)],
#  '2016-4 week: 16': [('#tornado', 3892),
#   ('#uruguay', 285),
#   ('#uruguay.', 210),
#   ('#kswx', 210),
#   ('#weather', 192),
#   ('#okwx', 170),
#   ('#txwx', 164),
#   ('#dolores', 158),
#   ('#tornado,', 97),
#   ('#tornade', 94),
#   ('#news', 86),
#   ('#wx', 83),
#   ('#storm', 81),
#   ('#tornado:', 77),
#   ('#ilwx', 74),
#   ('#hail', 73),
#   ('#camera', 73),
#   ('#tornado.', 70),
#   ('#urugay', 50),
#   ('#laddonia', 49)],
#  '2016-4 week: 17': [('#tornado', 11784),
#   ('#okwx', 999),
#   ('#txwx', 765),
#   ('#kswx', 648),
#   ('#newx', 559),
#   ('#weather', 505),
#   ('#tornadowarning', 424),
#   ('#oklahoma', 378),
#   ('#wx', 372),
#   ('#texas', 362),
#   ('#inwx', 319),
#   ('#hail', 318),
#   ('#storm', 245),
#   ('#severe', 237),
#   ('#mnwx', 224),
#   ('#severeweather', 220),
#   ('#lindale', 217),
#   ('#news', 205),
#   ('#iawx', 171),
#   ('#ok', 162)],
#  '2016-5 week: 17': [('#tornado', 387),
#   ('#weather', 63),
#   ('#wx', 59),
#   ('#news', 55),
#   ('#txwx', 34),
#   ('#hail', 32),
#   ('#etxwx', 29),
#   ('#flood', 29),
#   ('#cbs19wx', 28),
#   ('#lindale', 27),
#   ('#fire', 27),
#   ('#storm', 17),
#   ('#arwx', 16),
#   ('#lawx', 14),
#   ('#japan', 14),
#   ('#nowplaying', 14),
#   ('#tornado-grenade', 14),
#   ('#epweek', 13),
#   ('#rock', 11),
#   ('#pop', 11)],
#  '2016-5 week: 18': [('#tornado', 2289),
#   ('#inwx', 241),
#   ('#indianapolis', 115),
#   ('#weather', 75),
#   ('#hail', 69),
#   ('#wx', 63),
#   ('#kswx', 55),
#   ('#txwx', 53),
#   ('#indiana', 47),
#   ('#mowx', 44),
#   ('#news', 43),
#   ('#sgf', 43),
#   ('#md', 41),
#   ('#lightning', 41),
#   ('#stormhour', 40),
#   ('#okwx', 40),
#   ('#nwod', 40),
#   ('#cbs19wx', 36),
#   ('#breaking', 34),
#   ('#tornado.', 34)]}

# %% [markdown]
# Q8. Which twitter users are the most mentioned?

# %%
mostMentions = []
for index, tweet in tweets.iterrows(): 
    text = str(tweet['text']).lower()
    if len(text) > 0:        
        for word in text.split():
            if word[0] == '@':
                mostMentions.append(word)
Counter(mostMentions).most_common()[:25]
# Out:
# [('@weatherchannel:', 12899),
#  ('@stormchaser4850:', 5490),
#  ('@mark_tarello:', 3883),
#  ('@weathernation:', 2686),
#  ('@reedtimmertvn:', 1916),
#  ('@gjmccarthy:', 1751),
#  ('@txstormchasers:', 1504),
#  ('@', 1340),
#  ('@nwsfortworth:', 1275),
#  ('@tornadotrackers:', 1228),
#  ('@stevewafb:', 1104),
#  ('@weatherchannel', 1052),
#  ('@brianjamesnbc5:', 975),
#  ('@chematierra:', 953),
#  ('@thestormreport:', 909),
#  ('@dallasnews.', 888),
#  ('@spann', 887),
#  ('@dallasnews', 850),
#  ('@basehunters:', 833),
#  ('@ameschopper5', 833),
#  ('@reedtimmertvn', 814),
#  ('@breakingweather:', 794),
#  ('@dallasnewsphoto:', 792),
#  ('@lacoandy', 786),
#  ('@samanthashahi:', 775)]

# %% [markdown]
# Q9. How frequently is each user mentioned during each month of the lifecycle?

# %%
users = {}
for k, t in allTweets.items():
    users[k] = []
    for tweet in t:
        text = str(tweet['text']).lower()
        if len(text) > 0 and text != 'nan':
            for word in text.split():
                if word[0] == "@":
                    users[k].append(word)
    users[k] = Counter(users[k]).most_common()[:20]
users
# Out:
# {'2015-11 week: 47': [('@climatenewsca:', 14),
#   ('@chaac_tlaloc:', 4),
#   ('@ecazatormentas:', 3),
#   ('@_evolvingplanet:', 2),
#   ('@ashleyybriggs', 2),
#   ('@afrmiami', 2),
#   ('@mariamrspr', 2),
#   ('@sunsentinel:', 2),
#   ('@sigaobrun0', 2),
#   ('@socialnewscorp', 2),
#   ('@velocitychasing:', 1),
#   ('@myweathercam:', 1),
#   ('@italianairforce:', 1),
#   ('@captureasecond:', 1),
#   ('@tornado_lux', 1),
#   ('@tornadotitans:', 1),
#   ('@eduardoeltiempo:', 1),
#   ('@johnmoralesnbc6:', 1),
#   ('@thunder106nj', 1),
#   ('@aimhighacademy.', 1)],
#  '2015-11 week: 48': [('@todonoticias:', 53),
#   ('@nateimpact', 42),
#   ('@dalalmusic:', 42),
#   ('@robindelano', 42),
#   ('@b_ubiquitous', 37),
#   ('@stormhour:', 35),
#   ('@tagesschau:', 31),
#   ('@weatherchannel:', 31),
#   ('@firebeatz:', 28),
#   ('@stormchasing:', 24),
#   ('@franccescofan:', 23),
#   ('@', 23),
#   ('@chasertv:', 23),
#   ('@tornadotitans:', 20),
#   ('@thoton:', 18),
#   ('@b_ubiquitous:', 17),
#   ('@mym0mmybrain:', 17),
#   ('@socialnewscorp', 17),
#   ('@rafterw59:', 17),
#   ('@univ_ciencia:', 15)],
#  '2015-11 week: 49': [('@djrae1981', 50),
#   ('@djrae1981:', 48),
#   ('@cicero_online:', 27),
#   ('@doctorchristian', 14),
#   ('@', 12),
#   ('@txstormchasers:', 9),
#   ('@nhsenglandldn', 9),
#   ('@givebloodnhs', 8),
#   ('@nhsengland', 8),
#   ('@fox5dc', 7),
#   ('@carrolltrust', 7),
#   ('@sgtcauserwmp', 7),
#   ('@fraser9529wmp', 7),
#   ('@crimeconspiracy', 7),
#   ('@fox5sandiego', 7),
#   ('@sarlou1983', 7),
#   ('@sarlou1212', 7),
#   ('@sarlou1283', 7),
#   ('@zohreen', 7),
#   ('@fox5vegas', 7)],
#  '2015-12 week: 49': [('@sarahmgellar:', 204),
#   ('@ernstvall:', 129),
#   ('@heuteshow:', 123),
#   ('@koufogiorgos:', 30),
#   ('@sputnikint:', 27),
#   ('@bbcworld)', 27),
#   ('@armyrecognition:', 24),
#   ('@opexnews:', 23),
#   ('@btsullivan91.', 19),
#   ('@forcesnews:', 18),
#   ('@socialnewscorp', 17),
#   ('@tornadotitans:', 16),
#   ('@aviateaddict', 14),
#   ('@broadwayworld:', 14),
#   ('@classicnavalair', 12),
#   ('@theaviationist', 12),
#   ('@planenut27', 12),
#   ('@dw_turkce:', 11),
#   ('@mundo_ecpe:', 11),
#   ('@stormchaser4850:', 11)],
#  '2015-12 week: 50': [('@weatherchannel:', 211),
#   ('@stormchaser4850:', 168),
#   ('@brookskhou:', 142),
#   ('@weathernation:', 99),
#   ('@reedtimmertvn:', 90),
#   ('@jdwilhelm7:', 84),
#   ('@miyashay:', 84),
#   ('@nwsportland.', 76),
#   ('@jdwilhelm7)', 73),
#   ('@mark_tarello:', 68),
#   ('@heuteshow:', 61),
#   ('@reedtimmertvn', 55),
#   ('@scatty59:', 44),
#   ('@breakingweather', 41),
#   ('@clumsycrafter:', 39),
#   ('@natgeo', 38),
#   ('@amiplanet:', 36),
#   ('@chaac_tlaloc:', 34),
#   ('@jeff_piotrowski:', 32),
#   ('@dnjohnson621', 31)],
#  '2015-12 week: 51': [('@presidenciamx:', 752),
#   ('@epn', 673),
#   ('@gobmx', 331),
#   ('@luisfelipe_p:', 271),
#   ('@702sydney', 141),
#   ('@rosario_robles_:', 138),
#   ('@eduridden:', 133),
#   ('@vanguardiamx:', 118),
#   ('@chematierra:', 88),
#   ('@nampix:', 70),
#   ('@engadine_rfb:', 57),
#   ('@pcsegob:', 51),
#   ('@abcnews:', 40),
#   ('@danielshawau:', 36),
#   ('@ecazatormentas', 36),
#   ('@segob_mx:', 32),
#   ('@dailytelegraph', 30),
#   ('@tornadotitans:', 29),
#   ('@ausnewsnetwork:', 28),
#   ('@weatherchannel:', 27)],
#  '2015-12 week: 52': [('@weatherchannel:', 2603),
#   ('@txstormchasers:', 1412),
#   ('@gjmccarthy:', 1384),
#   ('@stormchaser4850:', 932),
#   ('@brianjamesnbc5:', 903),
#   ('@ameschopper5', 807),
#   ('@dallasnews.', 759),
#   ('@samanthashahi:', 756),
#   ('@dallasnewsphoto:', 686),
#   ('@dallasnews', 664),
#   ('@weathernation:', 568),
#   ('@tornadotrackers:', 566),
#   ('@huskiesgowoo:', 541),
#   ('@gjmccarthy', 500),
#   ('@tvnweather', 440),
#   ('@nwsmemphis', 433),
#   ('@mark_tarello:', 422),
#   ('@crabblers:', 421),
#   ('@nbcdfw', 415),
#   ('@txstormchasers', 414)],
#  '2015-12 week: 53': [('@weatherchannel:', 526),
#   ('@nwsfortworth:', 421),
#   ('@gjmccarthy:', 365),
#   ('@dallasnews', 170),
#   ('@wxbrad:', 151),
#   ('@mark_tarello:', 135),
#   ('@drudge_report_:', 135),
#   ('@dallasnews.', 129),
#   ('@mhernandezwfaa:', 126),
#   ('@stormchaser4850:', 113),
#   ('@nbcdfw:', 110),
#   ('@newsbreakslive:', 108),
#   ('@techeblog:', 100),
#   ('@scottlaney72', 97),
#   ('@dallasnewsphoto:', 96),
#   ('@alwaysactions:', 84),
#   ('@emc_parker', 82),
#   ('@gjmccarthy', 75),
#   ('@txwx', 69),
#   ('@nbcdfw', 57)],
#  '2016-1 week: 1': [('@weatherchannel:', 318),
#   ('@stormchaser4850:', 139),
#   ('@wxdickey', 85),
#   ('@homedepot', 59),
#   ('@nbcdfw', 59),
#   ('@pcsegob:', 59),
#   ('@salarmyeds:', 59),
#   ('@archernbc5:', 58),
#   ('@baesystemsair', 54),
#   ('@bbmf_photog', 52),
#   ('@nbcdfw:', 51),
#   ('@aviateaddict', 49),
#   ('@4elementsphoto:', 48),
#   ('@imjaggla:', 45),
#   ('@wfaachannel8', 44),
#   ('@son_gong:', 38),
#   ('@severeweathereu', 38),
#   ('@stormhour:', 37),
#   ('@conceptgrp:', 36),
#   ('@hfusa', 36)],
#  '2016-1 week: 2': [('@weatherchannel:', 466),
#   ('@imascarenas:', 217),
#   ('@weatherchannel', 157),
#   ('@stormchaser4850:', 138),
#   ('@mynews13', 118),
#   ('@killianphoto:', 117),
#   ('@weathernation:', 110),
#   ('@reedtimmertvn', 99),
#   ('@stormteam8wfla', 97),
#   ('@jimcantore', 96),
#   ('@wesh', 96),
#   ('@ruffesfox13:', 86),
#   ('@heatherssox:', 78),
#   ('@', 57),
#   ('@sarasotasheriff:', 52),
#   ('@wfla', 51),
#   ('@srqcountygov', 45),
#   ('@johnmoralesnbc6:', 44),
#   ('@tornadotitans:', 41),
#   ('@wflamary:', 41)],
#  '2016-1 week: 3': [('@weatherchannel:', 210),
#   ('@sputnikint:', 65),
#   ('@heuteshow:', 64),
#   ('@imascarenas:', 54),
#   ('@extra3:', 52),
#   ('@', 44),
#   ('@njoyde:', 43),
#   ('@stormchaser4850:', 38),
#   ('@reedtimmertvn:', 36),
#   ('@0223comar:', 34),
#   ('@pcsegob:', 27),
#   ('@maxtsaparis:', 24),
#   ('@bundeswehrinfo-tornados:', 22),
#   ('@fritzde:', 21),
#   ('@wunderground:', 20),
#   ('@socialnewscorp', 20),
#   ('@nwstampabay:', 19),
#   ('@weatherchannel', 18),
#   ('@weathernation:', 18),
#   ('@baesystemsair', 18)],
#  '2016-1 week: 4': [('@weatherchannel:', 331),
#   ('@nwsmiami', 172),
#   ('@amhq', 111),
#   ('@stevencejas:', 111),
#   ('@johnmoralesnbc6:', 99),
#   ('@cbs12', 92),
#   ('@wsvn:', 81),
#   ('@wplglocal10:', 70),
#   ('@nbc6', 59),
#   ('@wplglocal10', 46),
#   ('@weathernation:', 45),
#   ('@wsvn', 43),
#   ('@stormchaser4850:', 43),
#   ('@reedtimmertvn:', 42),
#   ('@pbc_alerts:', 38),
#   ('@sdarabia:', 38),
#   ('@luannesorrell:', 37),
#   ('@7weather:', 37),
#   ('@pcsegob:', 33),
#   ('@cbs12:', 33)],
#  '2016-1 week: 53': [('@weatherchannel:', 70),
#   ('@nbcdfw:', 46),
#   ('@alcantara_alb:', 27),
#   ('@mark_tarello:', 25),
#   ('@humanityfirstuk:', 22),
#   ('@', 20),
#   ('@txstormchasers\x92', 18),
#   ('@humanityfirstuk', 18),
#   ('@jennybrownphoto', 18),
#   ('@tornadotrackers:', 17),
#   ('@ahmadiyyatimes:', 17),
#   ('@nbcdfw', 16),
#   ('@jamessmartlp', 15),
#   ('@reedtimmertvn:', 15),
#   ('@corysmithnbc5:', 14),
#   ('@mesocyclonicwx', 14),
#   ('@prairiechasers:', 13),
#   ('@pcsegob:', 11),
#   ('@tornadotitans:', 10),
#   ('@nwsfortworth:', 8)],
#  '2016-2 week: 5': [('@weatherchannel:', 1319),
#   ('@stormchaser4850:', 488),
#   ('@weathernation:', 337),
#   ('@stormchasetv', 210),
#   ('@connormccrorey:', 201),
#   ('@basehunters:', 198),
#   ('@thetxwxchaser', 187),
#   ('@mikecihla:', 164),
#   ('@cnnweather:', 161),
#   ('@amhq.', 134),
#   ('@stormchasetv:', 129),
#   ('@spann', 116),
#   ('@mauriciomacri', 110),
#   ('@reedtimmertvn:', 110),
#   ('@descamisadostuc:', 104),
#   ('@severestudios', 103),
#   ('@zoomradar:', 100),
#   ('@ftstewartarmy.', 98),
#   ('@ariweather:', 91),
#   ('@stuostro:', 87)],
#  '2016-2 week: 6': [('@patriciodobal:', 143),
#   ('@weatherchannel:', 77),
#   ('@mark_tarello:', 55),
#   ('@cptplanespotter:', 22),
#   ('@socialnewscorp', 19),
#   ('@ayorafernando', 17),
#   ('@btppaddington:', 16),
#   ('@jmesparcia:', 14),
#   ('@', 14),
#   ('@stormpics:', 14),
#   ('@bb5150avg', 12),
#   ('@shortyskutztown:', 12),
#   ('@mrrat395', 12),
#   ('@lumpie125', 12),
#   ('@deolhonotempo:', 12),
#   ('@ufeellucky', 12),
#   ('@_horatio_', 12),
#   ('@spad5017', 12),
#   ('@didcotrailwayc:', 11),
#   ('@nwsdesmoines:', 11)],
#  '2016-2 week: 7': [('@weatherchannel:', 537),
#   ('@stormchaser4850:', 321),
#   ('@mark_tarello:', 313),
#   ('@weathernation:', 142),
#   ('@cnnbrk', 106),
#   ('@mapcatch:', 101),
#   ('@nbc6', 95),
#   ('@wplglocal10:', 86),
#   ('@nwsmiami', 85),
#   ('@mikespearsnbc6:', 80),
#   ('@wsvn:', 66),
#   ('@reedtimmertvn:', 57),
#   ('@rt_america:', 48),
#   ('@cbs12', 47),
#   ('@thestormreport', 46),
#   ('@rotorfocus:', 45),
#   ('@nwsmobile', 45),
#   ('@chematierra:', 44),
#   ('@uniqyourwordart:', 44),
#   ('@michelewrighttv:', 38)],
#  '2016-2 week: 8': [('@weatherchannel:', 1835),
#   ('@stormchaser4850:', 1227),
#   ('@stevewafb:', 837),
#   ('@mark_tarello:', 507),
#   ('@nwsneworleans', 448),
#   ('@foxnews:', 293),
#   ('@fox8nola.', 283),
#   ('@weathernation:', 276),
#   ('@thestormreport:', 270),
#   ('@cajunhumphrey:', 195),
#   ('@reedtimmertvn:', 190),
#   ('@stuostro:', 182),
#   ('@weatherchannel', 166),
#   ('@bamasevere:', 166),
#   ('@stormchasernl:', 157),
#   ('@infometeoro:', 147),
#   ('@amhq', 143),
#   ('@michaeldemocker:', 139),
#   ('@wunderground:', 128),
#   ('@btsullivan91:', 127)],
#  '2016-2 week: 9': [('@stevewafb:', 93),
#   ('@nws:', 13),
#   ('@weathernation:', 9),
#   ('@readygov:', 9),
#   ('@purduescience', 9),
#   ('@weatherchannel:', 9),
#   ('@b_ubiquitous:', 9),
#   ('@drshepherd2013:', 8),
#   ('@timmelino:', 7),
#   ('@purdueunivnews:', 7),
#   ('@naturecomms', 7),
#   ('@mktippett', 6),
#   ('@prepareathon:', 6),
#   ('@travelsnchases:', 6),
#   ('@foxnews:', 6),
#   ('@distressline', 6),
#   ('@wxjerdman:', 5),
#   ('@climatesociety:', 5),
#   ('@sciforbes,', 5),
#   ('@duttypaul', 5)],
#  '2016-3 week: 10': [('@weatherchannel:', 840),
#   ('@nwsfortworth:', 295),
#   ('@reedtimmertvn:', 226),
#   ('@pcsegob:', 153),
#   ('@tornadotrackers:', 144),
#   ('@kvue', 120),
#   ('@kvue:', 95),
#   ('@breakingweather', 90),
#   ('@', 87),
#   ('@mark_tarello:', 79),
#   ('@weathernation:', 79),
#   ('@stormchaser4850:', 68),
#   ('@nbcdfw', 68),
#   ('@amhq', 60),
#   ('@chasertv:', 49),
#   ('@amandanbc5:', 47),
#   ('@velocitychasing:', 46),
#   ('@rrstormchasers:', 43),
#   ('@scemd:', 41),
#   ('@breakingweather:', 41)],
#  '2016-3 week: 11': [('@mark_tarello:', 339),
#   ('@reedtimmertvn:', 279),
#   ('@stormchaser4850:', 260),
#   ('@weathernation:', 245),
#   ('@weatherchannel:', 207),
#   ('@spann', 176),
#   ('@b_carp01:', 175),
#   ('@cnnweather:', 154),
#   ('@breakingweather:', 148),
#   ('@breakingweather', 139),
#   ('@bamwxcom', 132),
#   ('@stormhour:', 122),
#   ('@tornadotrackers:', 113),
#   ('@tompurdywi:', 111),
#   ('@khqa:', 109),
#   ('@', 98),
#   ('@met_mdclark', 98),
#   ('@suzannetwn:', 98),
#   ('@jason1913', 98),
#   ('@fox59', 95)],
#  '2016-3 week: 12': [('@weatherchannel:', 66),
#   ('@heuteshow:', 48),
#   ('@amhq', 40),
#   ('@nwstulsa:', 26),
#   ('@pcsegob:', 25),
#   ('@nwsindianapolis:', 24),
#   ('@stormchaser4850:', 24),
#   ('@didcotrailwayc:', 18),
#   ('@travelsnchases:', 16),
#   ('@weathernation:', 15),
#   ('@nwsfortworth:', 15),
#   ('@', 12),
#   ('@foreverchasin:', 9),
#   ('@jamessmartlp:', 9),
#   ('@neweatherwx:', 9),
#   ('@socialnewscorp', 6),
#   ('@basehunters:', 6),
#   ('@nwsspc', 6),
#   ('@wfaalauren:', 5),
#   ('@despiertamerica', 5)],
#  '2016-3 week: 13': [('@mark_tarello:', 525),
#   ('@weatherchannel:', 440),
#   ('@stormchaser4850:', 305),
#   ('@nwstulsa', 241),
#   ('@jamesaydelott', 196),
#   ('@bak_yn', 181),
#   ('@amhq', 141),
#   ('@fox23', 137),
#   ('@newson6', 130),
#   ('@reedtimmertvn:', 116),
#   ('@rrstormchasers:', 105),
#   ('@jamesvanfleet:', 92),
#   ('@weatherdan:', 85),
#   ('@im_hyper_af:', 82),
#   ('@jeff_piotrowski:', 81),
#   ('@edcaly5:', 80),
#   ('@weatherchannel', 77),
#   ('@fema:', 69),
#   ('@rockstargames', 69),
#   ('@thagallery_glry', 69)],
#  '2016-3 week: 9': [('@fema:', 120),
#   ('@stormchaser4850:', 120),
#   ('@weatherchannel:', 107),
#   ('@weathernation:', 97),
#   ('@bamasevere:', 67),
#   ('@stevewafb:', 32),
#   ('@spann', 30),
#   ('@foxnews:', 29),
#   ('@marcweinbergwx:', 29),
#   ('@amhq', 27),
#   ('@sciforbes', 26),
#   ('@drshepherd2013:', 25),
#   ('@nwsindianapolis:', 25),
#   ('@eduardoeltiempo:', 22),
#   ('@alastormtracker:', 21),
#   ('@markprater', 19),
#   ('@travelsnchases:', 19),
#   ('@richardwvua23', 19),
#   ('@jillgilardi', 18),
#   ('@jpdice_fox6', 18)],
#  '2016-4 week: 13': [('@weatherchannel:', 565),
#   ('@mark_tarello:', 280),
#   ('@stormchaser4850:', 191),
#   ('@fema:', 148),
#   ('@abc3340:', 122),
#   ('@nwsatlanta:', 114),
#   ('@bamasevere:', 103),
#   ('@thestormreport:', 87),
#   ('@robinsafb_ga', 85),
#   ('@chematierra:', 80),
#   ('@weathernation:', 70),
#   ('@operation_chase:', 69),
#   ('@nwsatlanta', 50),
#   ('@wgxanews', 47),
#   ('@abc7news', 46),
#   ('@steverudinabc7:', 45),
#   ('@atlantawxman', 43),
#   ('@primerimpacto', 43),
#   ('@uninoticias', 43),
#   ('@eduardoeltiempo:', 42)],
#  '2016-4 week: 14': [('@weatherchannel:', 666),
#   ('@', 168),
#   ('@amhq', 153),
#   ('@reedtimmertvn:', 134),
#   ('@northeast_blog:', 123),
#   ('@reedtimmertvn', 83),
#   ('@paulfox13:', 76),
#   ('@jimcantore', 66),
#   ('@stormhour:', 49),
#   ('@slimsy1901:', 48),
#   ('@cocalandya', 47),
#   ('@stormtrooperjay:', 47),
#   ('@bombabelloto', 47),
#   ('@chematierra:', 46),
#   ('@jason1913', 45),
#   ('@beprepared_com,', 43),
#   ('@nwschicago:', 41),
#   ('@nadal_ben:', 41),
#   ('@mark_tarello:', 37),
#   ('@nwsnashville:', 37)],
#  '2016-4 week: 15': [('@lacoandy', 764),
#   ('@beprepared_com,', 438),
#   ('@cnnee:', 389),
#   ('@mark_tarello:', 343),
#   ('@reddeemergencia:', 339),
#   ('@estacion_bcp', 321),
#   ('@estacion_bcp:', 303),
#   ('@weatherchannel:', 252),
#   ('@reddeemergencia', 234),
#   ('@webcamsdemexico:', 230),
#   ('@emunizok:', 225),
#   ('@livestormsmedia:', 200),
#   ('@chematierra:', 189),
#   ('@noaaresearch:', 185),
#   ('@skyalertstorm:', 182),
#   ('@weathernation', 169),
#   ('@weatherlivetv', 168),
#   ('@stormhour:', 161),
#   ('@boleadorcharrua:', 154),
#   ('@weathernetwork:', 154)],
#  '2016-4 week: 16': [('@beprepared_com,', 272),
#   ('@weatherchannel:', 251),
#   ('@danielshawau:', 114),
#   ('@reddeemergencia', 113),
#   ('@lacoandy:', 113),
#   ('@webcamsdemexico:', 112),
#   ('@estacion_bcp:', 97),
#   ('@stormchasing:', 96),
#   ('@meteovilles:', 92),
#   ('@amhq:', 73),
#   ('@cdcemergency:', 72),
#   ('@nwschicago:', 64),
#   ('@prepareathon', 62),
#   ('@stormchaser4850:', 52),
#   ('@velocitychasing:', 49),
#   ('@readygov:', 48),
#   ('@meteo_reporter)', 45),
#   ('@', 41),
#   ('@breakingweather:', 38),
#   ('@amhq', 34)],
#  '2016-4 week: 17': [('@weatherchannel:', 735),
#   ('@stormchaser4850:', 666),
#   ('@mark_tarello:', 659),
#   ('@meanstreetsoma', 497),
#   ('@fema:', 331),
#   ('@ketv', 290),
#   ('@chiiikaiiizu:', 243),
#   ('@weathernation:', 200),
#   ('@cnnweather:', 177),
#   ('@reedtimmertvn:', 170),
#   ('@nwschicago:', 153),
#   ('@basehunters:', 142),
#   ('@prepareathon', 141),
#   ('@rt_com:', 135),
#   ('@velocitychasing:', 133),
#   ('@readygov:', 127),
#   ('@operation_chase:', 113),
#   ('@warntornado:', 108),
#   ('@', 106),
#   ('@trooperbenkhp:', 105)],
#  '2016-5 week: 17': [('@aromero_wx', 27),
#   ('@_evolvingplanet:', 25),
#   ('@livewxradar:', 24),
#   ('@weathernation:', 15),
#   ('@weathernetwork:', 12),
#   ('@mark_tarello:', 12),
#   ('@mpalmertwc:', 12),
#   ('@erikamartinwx', 10),
#   ('@stormtrooperjay:', 8),
#   ('@warntornado:', 7),
#   ('@nwsshreveport', 7),
#   ('@breakingweather:', 7),
#   ('@wayne_c_hart:', 7),
#   ('@reedtimmertvn:', 7),
#   ('@m_fimpel', 6),
#   ('@stormchaser4850:', 6),
#   ('@bojorquezcbs:', 5),
#   ('@emekavoces:', 5),
#   ('@siwatson28:', 5),
#   ('@simonstormrider', 5)],
#  '2016-5 week: 18': [('@weatherchannel:', 196),
#   ('@reedtimmertvn:', 61),
#   ('@stormchaser4850:', 52),
#   ('@weathernation:', 44),
#   ('@93wibc:', 42),
#   ('@nwsspringfield:', 40),
#   ('@erikamartinwx:', 39),
#   ('@stormhour:', 39),
#   ('@stormtrooperjay:', 39),
#   ('@breakingweather:', 36),
#   ('@rtv6', 35),
#   ('@aromero_wx', 33),
#   ('@tbaker1023', 33),
#   ('@zachpillsbury:', 31),
#   ('@jenniewthr:', 27),
#   ('@boleadorcharrua:', 26),
#   ('@spad5017', 24),
#   ('@mrrat395', 24),
#   ('@lumpie125', 24),
#   ('@ufeellucky', 24)]}

# %% [markdown]
# Q10. What is the relationship between the volume of tweets you selected and the volume of tweets for other collections in the data set?

# %%
listJobIds = {187: "SuperBowl", 1196: "RIP", 2335: "earthquake",
              2567: "missouri", 2572: "teaparty", 2577: "worldseries"}

con = mdb.connect('opendata.missouri.edu', 'datascience', 'datascience', 'datascience');

with con.cursor() as cursor:
    for id, des in listJobIds.items():
        sql = 'SELECT count(*) FROM tweet WHERE job_id = ' + str(id)
        cursor.execute(sql)
        result = cursor.fetchone()
        print(str(id) + "-" + des + ": " + str(result[0]))
        result
# Out:
# 2577-worldseries: 2527317
# 2567-missouri: 8334281
# 1196-RIP: 9243906
# 187-SuperBowl: 3301977
# 2572-teaparty: 3617549
# 2335-earthquake: 935795
